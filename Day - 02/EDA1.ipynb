# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Datasets/Algerian_forest_fires_dataset.csv')

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df[df.isnull().any(axis = 1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,'Region'] = 0
df.loc[122:,'Region'] =1

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire        0.0
# ...

# %%
df['Region'] = df['Region'].astype(int)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   2     6  2012          30  73  13     4  55.7  2.7  7.8  0.6  2.9  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df = df.drop(122).reset_index(drop =True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    object
#  1   month        242 non-null    object
#  2   year         242 non-null    object
#  3   Temperature  242 non-null    object
#  4   RH           242 non-null    object
#  5   Ws           242 non-null    object
#  6   Rain         242 non-null    object
#  7   FFMC         242 non-null    object
#  8   DMC          242 non-null    object
#  9   DC           242 non-null    object
#  10  ISI          242 non-null    object
#  11  BUI          242 non-null    object
#  12  FWI          242 non-null    object
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.5+ KB

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int32
#  1   month        242 non-null    int32
#  2   year         242 non-null    int32
#  3   Temperature  242 non-null    int32
#  4   RH           242 non-null    int32
#  5   Ws           242 non-null    int32
#  6   Rain         242 non-null    object
#  7   FFMC         242 non-null    object
#  8   DMC          242 non-null    object
#  9   DC           242 non-null    object
#  10  ISI          242 non-null    object
#  11  BUI          242 non-null    object
#  12  FWI          242 non-null    object
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 21.9+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int32
#  1   month        242 non-null    int32
#  2   year         242 non-null    int32
#  3   Temperature  242 non-null    int32
#  4   RH           242 non-null    int32
#  5   Ws           242 non-null    int32
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.9+ KB

# %%
df['Classes'].map({'not fire':0 ,'fire'.strip() :1})
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 237    1
# 238    0
# 239    0
# 240    0
# 241    0
# Name: Classes, Length: 242, dtype: int64

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
np.where()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 237   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 238   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 239   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 240   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 241   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
# df.columns = df.columns.str.strip()
df['Classes'] = df['Classes'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # df.columns = df.columns.str.strip()
# ----> 2 df['Classes'] = df['Classes'].str.strip()
#
# NameError: name 'df' is not defined

# %%
df.Classes.value_counts()
# Out:
# fire        137
# not fire    105
# Name: Classes, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_3428\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.009796   NaN     0.097502 -0.072323  0.039560
# month       -0.009796  1.000000   NaN    -0.057232 -0.038046 -0.047156
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097502 -0.057232   NaN     1.000000 -0.651791 -0.285644
# RH          -0.072323 -0.038046   NaN    -0.651791  1.000000  0.248148
# Ws           0.039560 -0.047156   NaN    -0.285644  0.248148  1.000000
# Rain        -0.113399  0.034777   NaN    -0.326499  0.222604  0.171896
# FFMC         0.217140  0.009022   NaN     0.679270 -0.644536 -0.175324
# ...

# %%
df.to_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_3428\3648873261.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
def corr_rem(dataset, threshold):
    cor_col = set()
    corr_matrix = dataset.corr(numeric_only = True)
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i,j])) > threshold:
                colname = corr_matrix.columns[i]
                cor_col.add(colname)
    return cor_col

# %%
corr_rem(df_clean,0.85)
# Out:
# {'BUI', 'DC', 'FWI'}

# %%
df.drop(remove_col,axis = 1 , inplace = True)

# %%
df_clean = pd.read_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    105
# Name: Classes, dtype: int64

# %%
df_clean['Classes'] =df_clean['Classes'].map({'fire':1 , 'not fire':0})

# %%
df_clean.columns
# Out:
# Index(['Unnamed: 0', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler

# %%
df_clean  = pd.read_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
df_clean  = df_clean.drop('Unnamed: 0',axis =1)

# %%
df_clean.Classes.value_counts()
# Out:
# fire        137
# not fire    105
# Name: Classes, dtype: int64

# %%
df_clean.Classes = df_clean.Classes.map({'fire':1,'not fire':0})

# %%
df_clean.drop(columns = ['Unnamed: 0', 'day', 'month', 'year'],inplace  = True)

# %%
df_clean.drop(columns = ['BUI', 'DC'],inplace  = True)

# %%
df_clean
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  FWI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4  1.3  0.5        0       0
# 1             29  61  13   1.3  64.4   4.1  1.0  0.4        0       0
# 2             26  82  22  13.1  47.1   2.5  0.3  0.1        0       0
# 3             25  89  13   2.5  28.6   1.3  0.0  0.0        0       0
# 4             27  77  16   0.0  64.8   3.0  1.2  0.5        0       0
# ..           ...  ..  ..   ...   ...   ...  ...  ...      ...     ...
# 237           30  65  14   0.0  85.4  16.0  4.5  6.5        1       1
# 238           28  87  15   4.4  41.1   6.5  0.1  0.0        0       1
# 239           27  87  29   0.5  45.9   3.5  0.4  0.2        0       1
# 240           24  54  18   0.1  79.7   4.3  1.7  0.7        0       1
# 241           24  64  15   0.2  67.3   3.8  1.2  0.5        0       1
#
# [242 rows x 10 columns]

# %%
y = df_clean['FWI']

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 237    6.5
# 238    0.0
# 239    0.2
# 240    0.7
# 241    0.5
# Name: FWI, Length: 242, dtype: float64

# %%
X = df_clean.drop('FWI',axis =1)

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4  1.3        0       0
# 1             29  61  13   1.3  64.4   4.1  1.0        0       0
# 2             26  82  22  13.1  47.1   2.5  0.3        0       0
# 3             25  89  13   2.5  28.6   1.3  0.0        0       0
# 4             27  77  16   0.0  64.8   3.0  1.2        0       0
# ..           ...  ..  ..   ...   ...   ...  ...      ...     ...
# 237           30  65  14   0.0  85.4  16.0  4.5        1       1
# 238           28  87  15   4.4  41.1   6.5  0.1        0       1
# 239           27  87  29   0.5  45.9   3.5  0.4        0       1
# 240           24  54  18   0.1  79.7   4.3  1.7        0       1
# 241           24  64  15   0.2  67.3   3.8  1.2        0       1
#
# [242 rows x 9 columns]

# %%
remcol = corr_rem(X , 0.85)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_3428\452237990.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
df_clean.to_csv('Datasets/Algerian_forest_fires_dataset_cleaned.csv')

# %%
df_clean.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.009796   NaN     0.097502 -0.072323  0.039560
# month       -0.009796  1.000000   NaN    -0.057232 -0.038046 -0.047156
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097502 -0.057232   NaN     1.000000 -0.651791 -0.285644
# RH          -0.072323 -0.038046   NaN    -0.651791  1.000000  0.248148
# Ws           0.039560 -0.047156   NaN    -0.285644  0.248148  1.000000
# Rain        -0.113399  0.034777   NaN    -0.326499  0.222604  0.171896
# FFMC         0.217140  0.009022   NaN     0.679270 -0.644536 -0.175324
# DMC          0.488513  0.062810   NaN     0.486494 -0.407180 -0.005819
# DC           0.525822  0.122326   NaN     0.376720 -0.225293  0.075031
# ISI          0.175010  0.060385   NaN     0.604948 -0.686103  0.003408
# BUI          0.514349  0.080075   NaN     0.460533 -0.352357  0.026542
# ...

# %%
df_clean
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  FWI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4  1.3  0.5        0       0
# 1             29  61  13   1.3  64.4   4.1  1.0  0.4        0       0
# 2             26  82  22  13.1  47.1   2.5  0.3  0.1        0       0
# 3             25  89  13   2.5  28.6   1.3  0.0  0.0        0       0
# 4             27  77  16   0.0  64.8   3.0  1.2  0.5        0       0
# ..           ...  ..  ..   ...   ...   ...  ...  ...      ...     ...
# 237           30  65  14   0.0  85.4  16.0  4.5  6.5        1       1
# 238           28  87  15   4.4  41.1   6.5  0.1  0.0        0       1
# 239           27  87  29   0.5  45.9   3.5  0.4  0.2        0       1
# 240           24  54  18   0.1  79.7   4.3  1.7  0.7        0       1
# 241           24  64  15   0.2  67.3   3.8  1.2  0.5        0       1
#
# [242 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape , y_train.shape,y_test.shape
# Out:
# ((162, 9), (80, 9), (162,), (80,))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train_scaled = sc.fit_transform(X_train.values)
X_test_scaled = sc.transform(X_test.values)

# %%
sns.boxplot(X_train_scaled)
# Out:
# <Axes: >

# %%
sns.boxplot(X_train)
# Out:
# <Axes: >

# %%
plt.subplots(figsize = (20,10))
plt.subplot(1,2,1)
plt.ylim(0,250)
sns.boxplot(X_train)
plt.title("X_train before scale")
plt.subplot(1,2,2)
sns.boxplot(X_train_scaled)
plt.title("X_train after scale")
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_18312\4066468152.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'X_train after scale')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lr = LinearRegression()
lr.fit(X_train_scaled,y_train)
y_pred = lr.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)
print("mean absolute error = " , mae)
print("r2score  = ",r2score)
# Out:
# mean absolute error =  0.6581179311188514
# r2score  =  0.9808901726434271

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lr.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)
print("mean absolute error = " , mae)
print("r2score  = ",r2score)
# Out:
# mean absolute error =  1.1834369325146707
# r2score  =  0.9488900057003428

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)
print("mean absolute error = " , mae)
print("r2score  = ",r2score)
# Out:
# mean absolute error =  0.6934492162772152
# r2score  =  0.9796204203242791

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic = ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred = elastic.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)
print("mean absolute error = " , mae)
print("r2score  = ",r2score)
# Out:
# mean absolute error =  1.83614338735059
# r2score  =  0.8766035122742762

# %%
import pickle
pickle.dump(sc, open('scaler2.pkl','wb'))
# pickle.dump(ridge, open('ridge.pkl','wb'))

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI  Classes  Region
# 147           36  55  15   0.0  89.1  20.9   8.0        1       1
# 225           28  81  15   0.0  84.6  12.6   4.3        1       1
# 65            34  65  13   0.0  86.8  11.1   5.2        1       0
# 168           34  58  16   0.0  88.1  27.8   7.3        1       1
# 205           34  40  18   0.0  92.1  56.3  14.3        1       1
# ..           ...  ..  ..   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   0.2        0       0
# 14            28  80  17   3.1  49.4   3.0   0.4        0       0
# 92            25  76  17   7.2  46.0   1.3   0.2        0       0
# 179           36  56  16   0.0  88.9  23.8   8.2        1       1
# 102           30  77  21   1.8  58.5   1.9   1.1        0       0
#
# [162 rows x 9 columns]

# %%
df_clean = pd.read_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
df_clean
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  FWI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4  1.3  0.5        0       0
# 1             29  61  13   1.3  64.4   4.1  1.0  0.4        0       0
# 2             26  82  22  13.1  47.1   2.5  0.3  0.1        0       0
# 3             25  89  13   2.5  28.6   1.3  0.0  0.0        0       0
# 4             27  77  16   0.0  64.8   3.0  1.2  0.5        0       0
# ..           ...  ..  ..   ...   ...   ...  ...  ...      ...     ...
# 237           30  65  14   0.0  85.4  16.0  4.5  6.5        1       1
# 238           28  87  15   4.4  41.1   6.5  0.1  0.0        0       1
# 239           27  87  29   0.5  45.9   3.5  0.4  0.2        0       1
# 240           24  54  18   0.1  79.7   4.3  1.7  0.7        0       1
# 241           24  64  15   0.2  67.3   3.8  1.2  0.5        0       1
#
# [242 rows x 10 columns]

# %%
df_
