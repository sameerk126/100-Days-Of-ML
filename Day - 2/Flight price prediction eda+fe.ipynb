# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_excel("Dataset/flight_train.xlsx")

# %%
df_train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df_test = pd.read_excel("Dataset/flight_test.xlsx")

# %%
df = df_train.append(df_test)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_12492\925505788.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
df['Additional_Info'].value_counts()
# Out:
# No info                         10493
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 1 Short layover                     1
# Red-eye flight                      1
# 2 Long layover                      1
# Name: Additional_Info, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
df.Source.unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df.Destination.unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df[['day','month','year'] ]= df['Date_of_Journey'].str.split('/',expand = True)

# %%
df.drop('Date_of_Journey' , axis = 1,inplace = True)

# %%
df.day = df.day.astype(int)

# %%
df.month = df.month.astype(int)

# %%
df.year = df.year.astype(int)

# %%
df['Arrival_Time'] = df.Arrival_Time.str.split(' ').str[0]

# %%
df['Arrival_Hour'] = df.Arrival_Time.str.split(':').str[0]

# %%
df['Arrival_Minutes'] = df.Arrival_Time.str.split(':').str[1]

# %%
df.drop("Arrival_Time", axis = 1 , inplace  = True)

# %%
df["Arrival_Hour"] = df.Arrival_Hour.astype(int)
df['Arrival_Minutes']= df.Arrival_Minutes.astype(int)

# %%
df['Dep_hour'] = df.Dep_Time.str.split(':').str[0]

# %%
df['Dep_Minutes'] = df.Dep_Time.str.split(':').str[1]

# %%
df.drop('Dep_Time' , axis = 1, inplace = True)

# %%
df['Dep_Minutes'] = df['Dep_Minutes'].astype(int)

# %%
df['Dep_hour'] = df['Dep_hour'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   day              13354 non-null  int32
#  9   month            13354 non-null  int32
#  10  year             13354 non-null  int32
#  11  Arrival_Hour     13354 non-null  int32
#  12  Arrival_Minutes  13354 non-null  int32
#  13  Dep_hour         13354 non-null  int32
#  14  Dep_Minutes      13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.8+ MB

# %%
df.Total_Stops.unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops'] = df.Total_Stops.map({'non-stop':0 , '2 stops':2, '1 stop':1,'3 stops':3 ,'4 stops': 4 })

# %%
df['Total_Stops'] =df['Total_Stops'].fillna(1)

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# day                   0
# month                 0
# year                  0
# Arrival_Hour          0
# Arrival_Minutes       0
# Dep_hour              0
# Dep_Minutes           0
# dtype: int64

# %%
df.drop('Route' ,axis = 1  ,inplace = True)

# %%
df.Duration
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#          ...
# 2666    23h 55m
# 2667     2h 35m
# 2668     6h 35m
# 2669    15h 15m
# 2670    14h 20m
# Name: Duration, Length: 13354, dtype: object

# %%
df1=df

# %%
df1['Duration_hour'] = df.Duration.str.split('h').str[0]

# %%
df1['Duration_min'] =df.Duration.str.split('m').str[0].str.split(' ').str[1]

# %%
# df1['Duration_hour'] = df1['Dep_hour'].map({'5m':5 , 'NA':0})

# %%
df1.Duration_hour = df.Duration_hour.replace('5m',5)

# %%
# df1.Duration_hour = 60 * df1.Duration_hour.astype(int)

# %%
df1['Duration_1'] = df1.Duration_min + df1.Duration_hour

# %%
df1.Duration_min = df1.Duration_min.astype(int)

# %%
df
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  day  month  year  Arrival_Hour  \
# 0            No info   3897.0   24      3  2019             1
# ...

# %%
df.drop('Total_Duration' , axis = 1, inplace = True)

# %%
df
# Out:
#       Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0           3  Banglore   New Delhi          0.0         No info   3897.0
# 1           1   Kolkata    Banglore          2.0         No info   7662.0
# 2           4     Delhi      Cochin          2.0         No info  13882.0
# 3           3   Kolkata    Banglore          1.0         No info   6218.0
# 4           3  Banglore   New Delhi          1.0         No info  13302.0
# ...       ...       ...         ...          ...             ...      ...
# 2666        1   Kolkata    Banglore          1.0         No info      NaN
# 2667        3   Kolkata    Banglore          0.0         No info      NaN
# 2668        4     Delhi      Cochin          1.0         No info      NaN
# 2669        1     Delhi      Cochin          1.0         No info      NaN
# 2670        6     Delhi      Cochin          1.0         No info      NaN
#
#       day  month  year  Arrival_Hour  Arrival_Minutes  Dep_hour  Dep_Minutes  \
# ...

# %%
df.drop([6474,2660] ,inplace = True)

# %%
df.drop(['Duration_hour', 'Duration_min'] ,axis =1 , inplace = True)

# %%
df.rename(columns = {'Duration_1':'Duration'} , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  int32
#  1   Source           13351 non-null  int32
#  2   Destination      13351 non-null  int32
#  3   Total_Stops      13351 non-null  float64
#  4   Additional_Info  13351 non-null  int32
#  5   Price            10681 non-null  float64
#  6   day              13351 non-null  int32
#  7   month            13351 non-null  int32
#  8   year             13351 non-null  int32
#  9   Arrival_Hour     13351 non-null  int32
#  10  Arrival_Minutes  13351 non-null  int32
#  11  Dep_hour         13351 non-null  int32
#  12  Dep_Minutes      13351 non-null  int32
#  13  Duration         13351 non-null  int32
# dtypes: float64(2), int32(12)
# memory usage: 938.7 KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Airline'] = le.fit_transform(df['Airline'])

# %%
df['Source'] = le.fit_transform(df['Source'])

# %%
df['Destination'] = le.fit_transform(df['Destination'])

# %%
df['Additional_Info'] = le.fit_transform(df['Additional_Info'])

# %%
df_test = df[df['Price'].isnull()]
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info  Price  day  \
# 0           4       2            1          1.0                8    NaN    6
# 1           3       3            0          1.0                8    NaN   12
# 2           4       2            1          1.0                5    NaN   21
# 3           6       2            1          1.0                8    NaN   21
# 4           0       0            2          0.0                8    NaN   24
# ...       ...     ...          ...          ...              ...    ...  ...
# 2666        1       3            0          1.0                8    NaN    6
# 2667        3       3            0          0.0                8    NaN   27
# 2668        4       2            1          1.0                8    NaN    6
# 2669        1       2            1          1.0                8    NaN    6
# 2670        6       2            1          1.0                8    NaN   15
#
# ...

# %%
pd.get_dummies(df,columns= ['Airline','Source','Destination','Additional_Info'],drop_first = True )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 pd.get_dummies(df,columns= ['Airline','Source','Destination','Additional_Info'],drop_first = True , inplace = True)
#
# TypeError: get_dummies() got an unexpected keyword argument 'inplace'

# %%
df
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0           3       0            5          0.0                8   3897.0
# 1           1       3            0          2.0                8   7662.0
# 2           4       2            1          2.0                8  13882.0
# 3           3       3            0          1.0                8   6218.0
# 4           3       0            5          1.0                8  13302.0
# ...       ...     ...          ...          ...              ...      ...
# 2666        1       3            0          1.0                8      NaN
# 2667        3       3            0          0.0                8      NaN
# 2668        4       2            1          1.0                8      NaN
# 2669        1       2            1          1.0                8      NaN
# 2670        6       2            1          1.0                8      NaN
#
#       day  month  year  Arrival_Hour  Arrival_Minutes  Dep_hour  Dep_Minutes  \
# ...
