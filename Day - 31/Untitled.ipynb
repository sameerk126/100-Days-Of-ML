# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
df
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC  ISI  FWI  Classes  \
# 0             0           29  57  18   0.0  65.7   3.4  1.3  0.5        0
# 1             1           29  61  13   1.3  64.4   4.1  1.0  0.4        0
# 2             2           26  82  22  13.1  47.1   2.5  0.3  0.1        0
# 3             3           25  89  13   2.5  28.6   1.3  0.0  0.0        0
# 4             4           27  77  16   0.0  64.8   3.0  1.2  0.5        0
# ..          ...          ...  ..  ..   ...   ...   ...  ...  ...      ...
# 237         237           30  65  14   0.0  85.4  16.0  4.5  6.5        1
# 238         238           28  87  15   4.4  41.1   6.5  0.1  0.0        0
# 239         239           27  87  29   0.5  45.9   3.5  0.4  0.2        0
# 240         240           24  54  18   0.1  79.7   4.3  1.7  0.7        0
# 241         241           24  64  15   0.2  67.3   3.8  1.2  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_cleaned.csv')

# %%
df
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC  ISI  FWI  Classes  \
# 0             0           29  57  18   0.0  65.7   3.4  1.3  0.5        0
# 1             1           29  61  13   1.3  64.4   4.1  1.0  0.4        0
# 2             2           26  82  22  13.1  47.1   2.5  0.3  0.1        0
# 3             3           25  89  13   2.5  28.6   1.3  0.0  0.0        0
# 4             4           27  77  16   0.0  64.8   3.0  1.2  0.5        0
# ..          ...          ...  ..  ..   ...   ...   ...  ...  ...      ...
# 237         237           30  65  14   0.0  85.4  16.0  4.5  6.5        1
# 238         238           28  87  15   4.4  41.1   6.5  0.1  0.0        0
# 239         239           27  87  29   0.5  45.9   3.5  0.4  0.2        0
# 240         240           24  54  18   0.1  79.7   4.3  1.7  0.7        0
# 241         241           24  64  15   0.2  67.3   3.8  1.2  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
X = df.drop(columns = ['Classes','Unnamed: 0'])

# %%
y = df['Classes']

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI   FWI  Region
# 147           36  55  15   0.0  89.1  20.9   8.0  12.0       1
# 225           28  81  15   0.0  84.6  12.6   4.3   5.7       1
# 65            34  65  13   0.0  86.8  11.1   5.2   6.1       0
# 168           34  58  16   0.0  88.1  27.8   7.3  13.0       1
# 205           34  40  18   0.0  92.1  56.3  14.3  31.1       1
# ..           ...  ..  ..   ...   ...   ...   ...   ...     ...
# 106           24  82  15   0.4  44.9   0.9   0.2   0.0       0
# 14            28  80  17   3.1  49.4   3.0   0.4   0.1       0
# 92            25  76  17   7.2  46.0   1.3   0.2   0.1       0
# 179           36  56  16   0.0  88.9  23.8   8.2  13.2       1
# 102           30  77  21   1.8  58.5   1.9   1.1   0.3       0
#
# [162 rows x 9 columns]

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
log_reg_pred = log_reg.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, classification_report , precision_score

# %%
pred  = log_reg_pred
print('Accurecy  = ', accuracy_score(y_test,log_reg_pred))
print(classification_report(y_test,log_reg_pred))
print(precision_score(y_test,log_reg_pred))
# Out:
# Accurecy  =  0.9625
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95        28
#            1       0.98      0.96      0.97        52
#
#     accuracy                           0.96        80
#    macro avg       0.96      0.96      0.96        80
# weighted avg       0.96      0.96      0.96        80
#
# 0.9803921568627451

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
svc_pred = svc.predict(X_test)

# %%
pred  = svc_pred
print('Accurecy  = ', accuracy_score(y_test,log_reg_pred))
print(classification_report(y_test,log_reg_pred))
print(precision_score(y_test,log_reg_pred))
# Out:
# Accurecy  =  0.9625
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95        28
#            1       0.98      0.96      0.97        52
#
#     accuracy                           0.96        80
#    macro avg       0.96      0.96      0.96        80
# weighted avg       0.96      0.96      0.96        80
#
# 0.9803921568627451

# %%
pickle.dump(svc, open('model.pkl', 'wb'))
