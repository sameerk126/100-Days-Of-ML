# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline

# %%
df_train = pd.read_csv('/kaggle/input/playground-series-s3e25/train.csv')

# %%
df_test = pd.read_csv('/kaggle/input/playground-series-s3e25/test.csv')

# %%
df = pd.concat([df_train,df_test])

# %%
df
# Out:
#          id  allelectrons_Total  density_Total  allelectrons_Average  \
# 0         0               100.0       0.841611             10.000000
# 1         1               100.0       7.558488             10.000000
# 2         2                76.0       8.885992             15.600000
# 3         3               100.0       8.795296             10.000000
# 4         4               116.0       9.577996             11.600000
# ...     ...                 ...            ...                   ...
# 6934  17341               446.0      36.135392              9.636364
# 6935  17342                36.0       3.550000             18.000000
# 6936  17343                68.0       4.545328             11.333333
# 6937  17344                40.0       2.334164              6.666667
# 6938  17345               134.0      17.590000             67.000000
#
#       val_e_Average  atomicweight_Average  ionenergy_Average  \
# 0          4.800000             20.612526          11.088100
# ...

# %%
df.drop('id',axis = 1,inplace =True)

# %%
df
# Out:
#       allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0                  100.0       0.841611             10.000000       4.800000
# 1                  100.0       7.558488             10.000000       4.800000
# 2                   76.0       8.885992             15.600000       5.600000
# 3                  100.0       8.795296             10.000000       4.800000
# 4                  116.0       9.577996             11.600000       4.800000
# ...                  ...            ...                   ...            ...
# 6934               446.0      36.135392              9.636364       4.636364
# 6935                36.0       3.550000             18.000000       4.000000
# 6936                68.0       4.545328             11.333333       5.333333
# 6937                40.0       2.334164              6.666667       4.000000
# 6938               134.0      17.590000             67.000000       5.000000
#
# ...

# %%
# print(sns.__version__)
# pip install --upgrade sns
# #

# %%
plt.scatter(x = df['allelectrons_Total'], y = df['Hardness'])

# %%
df[df['allelectrons_Total'] > 8000]
# Out:
#       allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 774               9852.0       8.511159              7.636364       3.676768
# 5493             15300.0     643.093804              8.027397       5.401274
# 5860             10116.0     502.575708              9.492063       4.825397
# 6772             10116.0     502.575708              5.781132       5.781132
#
#       atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 774              15.374870          13.123610            2.780505
# 5493             16.215127          12.976603            3.179236
# 5860             19.379077          11.213325            2.738565
# 6772             19.379077          12.976603            3.184434
#
#       R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 774                1.385051               0.458788         0.706986
# 5493               1.567945               0.737260         0.505030
# ...

# %%
df.drop(index = [774,5493,5860,6772],inplace = True)

# %%
df.head(3)
# Out:
#    allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0               100.0       0.841611                  10.0            4.8
# 1               100.0       7.558488                  10.0            4.8
# 2                76.0       8.885992                  15.6            5.6
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0             20.612526           11.08810               2.766
# 1             20.298893           12.04083               2.755
# 2             33.739258           12.08630               2.828
#
#    R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 0                  1.732                  0.860         0.496070
# 1                  1.631                  0.910         0.492719
# 2                  1.788                  0.864         0.481478
#
#    density_Average  Hardness
# 0          0.91457       6.0
# 1          0.71760       6.5
# 2          1.50633       2.5

# %%
plt.scatter(x = df['density_Total'], y = df['Hardness'])

# %%
df.head(3)
# Out:
#    allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0               100.0       0.841611                  10.0            4.8
# 1               100.0       7.558488                  10.0            4.8
# 2                76.0       8.885992                  15.6            5.6
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0             20.612526           11.08810               2.766
# 1             20.298893           12.04083               2.755
# 2             33.739258           12.08630               2.828
#
#    R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 0                  1.732                  0.860         0.496070
# 1                  1.631                  0.910         0.492719
# 2                  1.788                  0.864         0.481478
#
#    density_Average  Hardness
# 0          0.91457       6.0
# 1          0.71760       6.5
# 2          1.50633       2.5

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# # listing correated features
# def listing_coorelated(df,max_corr):
#     corr_matrix = df.corr()
#     corr_list=[]
#     for i in df.columns:
#         for j in df.columns:
#             if(i!=j and corr_matrix[i][j]>max_corr):
#                 corr_list.append(i)
#                 corr_list.append(j)
#     return corr_list

# %%
# listing_coorelated(df,0.80)

# %%
plt.scatter(x = df['allelectrons_Average'],y = df['Hardness'])

# %% [markdown]
# > **allelectrons_Average and hardness are inversly proportional****

# %%
plt.scatter(x =df['val_e_Average'],y= df['Hardness'])

# %%
plt.scatter(x =df['atomicweight_Average'],y= df['Hardness'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17338 entries, 0 to 6938
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     17338 non-null  float64
#  1   density_Total          17338 non-null  float64
#  2   allelectrons_Average   17338 non-null  float64
#  3   val_e_Average          17338 non-null  float64
#  4   atomicweight_Average   17338 non-null  float64
#  5   ionenergy_Average      17338 non-null  float64
#  6   el_neg_chi_Average     17338 non-null  float64
#  7   R_vdw_element_Average  17338 non-null  float64
#  8   R_cov_element_Average  17338 non-null  float64
#  9   zaratio_Average        17338 non-null  float64
#  10  density_Average        17338 non-null  float64
#  11  Hardness               10403 non-null  float64
# dtypes: float64(12)
# memory usage: 1.7 MB

# %%
df
# Out:
#       allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0                  100.0       0.841611             10.000000       4.800000
# 1                  100.0       7.558488             10.000000       4.800000
# 2                   76.0       8.885992             15.600000       5.600000
# 3                  100.0       8.795296             10.000000       4.800000
# 4                  116.0       9.577996             11.600000       4.800000
# ...                  ...            ...                   ...            ...
# 6934               446.0      36.135392              9.636364       4.636364
# 6935                36.0       3.550000             18.000000       4.000000
# 6936                68.0       4.545328             11.333333       5.333333
# 6937                40.0       2.334164              6.666667       4.000000
# 6938               134.0      17.590000             67.000000       5.000000
#
# ...
