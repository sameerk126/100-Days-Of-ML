# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv('Datasets/train.csv')

# %%
df_test = pd.read_csv('Datasets/test.csv')

# %%
df_train
# Out:
#         id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        0     999  D-penicillamine  21532   M       N            N       N
# 1        1    2574          Placebo  19237   F       N            N       N
# 2        2    3428          Placebo  13727   F       N            Y       Y
# 3        3    2576          Placebo  18460   F       N            N       N
# 4        4     788          Placebo  16658   F       N            Y       N
# ...    ...     ...              ...    ...  ..     ...          ...     ...
# 7900  7900    1166  D-penicillamine  16839   F       N            N       N
# 7901  7901    1492          Placebo  17031   F       N            Y       N
# 7902  7902    1576  D-penicillamine  25873   F       N            N       Y
# 7903  7903    3584  D-penicillamine  22960   M       N            Y       N
# 7904  7904    1978  D-penicillamine  19237   F       N            N       N
#
# ...

# %%
df = df_train.append(df_test)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_14312\925505788.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test)

# %%
df
# Out:
#          id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0         0     999  D-penicillamine  21532   M       N            N       N
# 1         1    2574          Placebo  19237   F       N            N       N
# 2         2    3428          Placebo  13727   F       N            Y       Y
# 3         3    2576          Placebo  18460   F       N            N       N
# 4         4     788          Placebo  16658   F       N            Y       N
# ...     ...     ...              ...    ...  ..     ...          ...     ...
# 5266  13171    2870          Placebo  12279   F       N            N       N
# 5267  13172    1770          Placebo  24803   F       N            N       N
# 5268  13173    3707  D-penicillamine  16990   F       N            Y       N
# 5269  13174    1216          Placebo  11773   F       N            N       N
# 5270  13175    2272  D-penicillamine  21600   F       N            N       N
#
# ...

# %%
df.drop('id',axis = 1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13176 entries, 0 to 5270
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         13176 non-null  int64
#  1   Drug           13176 non-null  int64
#  2   Age            13176 non-null  int64
#  3   Sex            13176 non-null  object
#  4   Ascites        13176 non-null  object
#  5   Hepatomegaly   13176 non-null  object
#  6   Spiders        13176 non-null  object
#  7   Edema          13176 non-null  object
#  8   Bilirubin      13176 non-null  float64
#  9   Cholesterol    13176 non-null  float64
#  10  Albumin        13176 non-null  float64
#  11  Copper         13176 non-null  float64
#  12  Alk_Phos       13176 non-null  float64
#  13  SGOT           13176 non-null  float64
#  14  Tryglicerides  13176 non-null  float64
#  15  Platelets      13176 non-null  float64
#  16  Prothrombin    13176 non-null  float64
# ...

# %%
df['Drug'].unique()
# Out:
# array(['D-penicillamine', 'Placebo'], dtype=object)

# %%
df['Drug'] = df['Drug'].map({'D-penicillamine':0, 'Placebo':1})

# %%
df['Drug'].isnull().sum()
# Out:
# 0

# %%
df['Sex'] = df['Sex'].map({'M':1, 'F':0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13176 entries, 0 to 5270
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         13176 non-null  int64
#  1   Drug           13176 non-null  int64
#  2   Age            13176 non-null  int64
#  3   Sex            13176 non-null  int64
#  4   Ascites        13176 non-null  int64
#  5   Hepatomegaly   13176 non-null  int64
#  6   Spiders        13176 non-null  int64
#  7   Edema          13176 non-null  object
#  8   Bilirubin      13176 non-null  float64
#  9   Cholesterol    13176 non-null  float64
#  10  Albumin        13176 non-null  float64
#  11  Copper         13176 non-null  float64
#  12  Alk_Phos       13176 non-null  float64
#  13  SGOT           13176 non-null  float64
#  14  Tryglicerides  13176 non-null  float64
#  15  Platelets      13176 non-null  float64
#  16  Prothrombin    13176 non-null  float64
# ...

# %%
df['Ascites'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['Ascites'] = df['Ascites'].map({'N':0, 'Y':1})

# %%
df['Hepatomegaly'] = df['Hepatomegaly'].map({'N':0, 'Y':1})

# %%
df['Spiders'] = df['Spiders'].map({'N':0, 'Y':1})

# %%
df['Edema'] = df['Edema'].map({'N':2, 'Y':1, 'S':0})

# %%
df['Edema'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13176 entries, 0 to 5270
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         13176 non-null  int64
#  1   Drug           13176 non-null  int64
#  2   Age            13176 non-null  int64
#  3   Sex            13176 non-null  int64
#  4   Ascites        13176 non-null  int64
#  5   Hepatomegaly   13176 non-null  int64
#  6   Spiders        13176 non-null  int64
#  7   Edema          13176 non-null  int64
#  8   Bilirubin      13176 non-null  float64
#  9   Cholesterol    13176 non-null  float64
#  10  Albumin        13176 non-null  float64
#  11  Copper         13176 non-null  float64
#  12  Alk_Phos       13176 non-null  float64
#  13  SGOT           13176 non-null  float64
#  14  Tryglicerides  13176 non-null  float64
#  15  Platelets      13176 non-null  float64
#  16  Prothrombin    13176 non-null  float64
# ...

# %%
df
# Out:
#       N_Days  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0        999     0  21532    1        0             0        0      2
# 1       2574     1  19237    0        0             0        0      2
# 2       3428     1  13727    0        0             1        1      1
# 3       2576     1  18460    0        0             0        0      2
# 4        788     1  16658    0        0             1        0      2
# ...      ...   ...    ...  ...      ...           ...      ...    ...
# 5266    2870     1  12279    0        0             0        0      2
# 5267    1770     1  24803    0        0             0        0      2
# 5268    3707     0  16990    0        0             1        0      2
# 5269    1216     1  11773    0        0             0        0      2
# 5270    2272     0  21600    0        0             0        0      2
#
#       Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df['Status'] = df['Status'].map({'D':1, 'C':2, 'CL':0})

# %%
df['Status'].value_counts()
# Out:
# C     4965
# D     2665
# CL     275
# Name: Status, dtype: int64

# %%
# df_train_data = 
df_test_X = df[df['Status'].isnull()]

# %%
df_train_X = df[~df['Status'].isnull()]

# %%
df_train_y = df_train_X['Status']

# %%
df_train_X.drop('Status',axis = 1,inplace  = True)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_14312\3022140498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_X.drop('Status',axis = 1,inplace  = True)

# %%
df_test_X.drop('Status',axis = 1,inplace  = True)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_14312\2415691432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_X.drop('Status',axis = 1,inplace  = True)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
# X_train_scaled = sc.fit_transform(X_train)
# X_test_scaled = sc.transform(X_test)
X_train, X_test, y_train, y_test = train_test_split(df_train_X, df_train_y, test_size=0.33, random_state=42)

# %%
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg  = LogisticRegression()

# %%
log_reg.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
out = log_reg.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
out
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
out = pd.DataFrame(out)
out.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
out.value_counts()
# Out:
# 1.0    2609
# dtype: int64
