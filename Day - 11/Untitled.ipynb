# %%
import os
from sklearn.tree import export_graphviz
import six
import pydot
from sklearn import tree
dotfile = six.StringIO()
i_tree = 0
for tree_in_forest in estimator.estimators_:
    export_graphviz(tree_in_forest,out_file='tree.dot',
    feature_names=col,
    filled=True,
    rounded=True)
    (graph,) = pydot.graph_from_dot_file('tree.dot')
    name = 'tree' + str(i_tree)
    graph.write_png(name+  '.png')
    os.system('dot -Tpng tree.dot -o tree.png')
    i_tree +=1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from sklearn.tree import export_graphviz
#       3 import six
# ----> 4 import pydot
#       5 from sklearn import tree
#       6 dotfile = six.StringIO()
#
# ModuleNotFoundError: No module named 'pydot'

# %%
pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(loaded_model,feature_names=X.columns,filled=True,rounded=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 export_graphviz(loaded_model,feature_names=X.columns,filled=True,rounded=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_export.py:888, in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     869     out_file = StringIO()
#     871 exporter = _DOTTreeExporter(
#     872     out_file=out_file,
#     873     max_depth=max_depth,
#    (...)
#     886     fontname=fontname,
#     887 )
# --> 888 exporter.export(decision_tree)
#     890 if return_string:
#     891     return exporter.out_file.getvalue()
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_export.py:461, in _DOTTreeExporter.export(self, decision_tree)
# ...

# %%
loaded_model = pickle.load(open('model.pkl', 'rb'))

# %%
import pandas as pd
df= pd.read_csv('Datasets/Arrhythmia.csv')

# %%
X.drop('type',axis=1,inplace=True)

# %%
plot_tree(loaded_model.estimators_[0], feature_names=X.columns, class_names=['N','VEB','SVEB','F'], filled=True, rounded=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_tree(loaded_model.estimators_[0], feature_names=X.columns, class_names=['N','VEB','SVEB','F'], filled=True, rounded=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_export.py:194, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     179 check_is_fitted(decision_tree)
#     181 exporter = _MPLTreeExporter(
#     182     max_depth=max_depth,
#     183     feature_names=feature_names,
#    (...)
#     192     fontsize=fontsize,
#     193 )
# --> 194 return exporter.export(decision_tree, ax=ax)
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_export.py:655, in _MPLTreeExporter.export(self, decision_tree, ax)
#     653 ax.clear()
#     654 ax.set_axis_off()
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
df.type.value_counts()
# Out:
# N       90083
# VEB      7009
# SVEB     2779
# F         803
# Q          15
# Name: type, dtype: int64

# %%
df = pd.read_csv('Arrithmia_cleanes.csv')
y = df['type']

# %%
X = df
X.drop('record',axis = 1  , inplace  = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
num_trees = len(rf_classifier.estimators_)

# %%
num_trees
# Out:
# 100

# %%
plt.figure(figsize=(100, 50))
plot_tree(rf_classifier.estimators_[0], feature_names=X.columns, class_names=['N', 'SVEB', 'VEB', 'F'], filled=True, rounded=True)
plt.show()

# %%
y.unique()
# Out:
# array(['N', 'SVEB', 'VEB', 'F'], dtype=object)
