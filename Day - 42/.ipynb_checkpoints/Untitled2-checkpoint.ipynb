# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv('Datasets/train.csv')
df_test = pd.read_csv('Datasets/test.csv')
df = df_train.append(df_test)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_9172\2126509140.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test)

# %%
df.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.drop(columns = ['id', 'CustomerId', 'Surname'],inplace  = True)

# %%
df
# Out:
#         CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0               668    France    Male  33.0       3       0.00              2
# 1               627    France    Male  33.0       1       0.00              2
# 2               678    France    Male  40.0      10       0.00              2
# 3               581    France    Male  34.0       2  148882.54              1
# 4               716     Spain    Male  33.0       5       0.00              2
# ...             ...       ...     ...   ...     ...        ...            ...
# 110018          570     Spain    Male  29.0       7  116099.82              1
# 110019          575    France  Female  36.0       4  178032.53              1
# 110020          712    France    Male  31.0       2       0.00              2
# 110021          709    France  Female  32.0       3       0.00              1
# 110022          621    France  Female  37.0       7   87848.39              1
#
# ...

# %%
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Geography'] = label_encoder.fit_transform(df['Geography'])
# 0 = France , 1 = Germeny , 2 = Spain
df['Gender'] = label_encoder.fit_transform(df['Gender'])
#1 = male ,0 = female

# %%
df
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 110018          570          2       1  29.0       7  116099.82
# 110019          575          0       0  36.0       4  178032.53
# 110020          712          0       1  31.0       2       0.00
# 110021          709          0       0  32.0       3       0.00
# 110022          621          0       0  37.0       7   87848.39
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
df
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 110018          570          2       1  29.0       7  116099.82
# 110019          575          0       0  36.0       4  178032.53
# 110020          712          0       1  31.0       2       0.00
# 110021          709          0       0  32.0       3       0.00
# 110022          621          0       0  37.0       7   87848.39
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
plt.figure(figsize=(12,6))
# sns.color_palette('tab10', as_cmap=True)

sns.histplot(x = df['CreditScore'], hue = df['Geography'] ,palette=['#000000','#F0EDCF','#40A2D8'])
# Out:
# <Axes: xlabel='CreditScore', ylabel='Count'>

# %%
#Data Distribution
g = sns.countplot(df, x="Geography")
g.set(xticklabels=["France", "Germany", "Spain"])
# (['France', 'Spain', 'Germany']
# Out:
# [[Text(0, 0, 'France'), Text(1, 0, 'Germany'), Text(2, 0, 'Spain')]]

# %%
g = sns.countplot(df, x = 'Gender')
g.set(xticklabels = ['Female','Male'])
# Out:
# [[Text(0, 0, 'Female'), Text(1, 0, 'Male')]]

# %%
df
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 110018          570          2       1  29.0       7  116099.82
# 110019          575          0       0  36.0       4  178032.53
# 110020          712          0       1  31.0       2       0.00
# 110021          709          0       0  32.0       3       0.00
# 110022          621          0       0  37.0       7   87848.39
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
sns.lineplot(x= df['Age'],y = df['Balance'])
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.axhline(y=6)
plt.axhline(y=4)
sns.lineplot(x = df['CreditScore'], y = df['Tenure'])
# Observation - for credit score more than 500 the ideal tenure is 4 to 6 months
# Out:
# <Axes: xlabel='CreditScore', ylabel='Tenure'>

# %%
sns.lineplot(x = df['Age'], y = df['NumOfProducts'])
# Out:
# <Axes: xlabel='Age', ylabel='NumOfProducts'>

# %%
sns.histplot(x = df['Age'],hue = df['HasCrCard'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# plt.figure(figsize=(12,6))
# sns.histplot(x = df['Age'],hue = df['IsActiveMember'])
# sns.lineplot(x = df['Age'],y = df['EstimatedSalary'])
df
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 110018          570          2       1  29.0       7  116099.82
# 110019          575          0       0  36.0       4  178032.53
# 110020          712          0       1  31.0       2       0.00
# 110021          709          0       0  32.0       3       0.00
# 110022          621          0       0  37.0       7   87848.39
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
df.to_csv('Datasets/df_cleaned.csv')

# %%
df
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 110018          570          2       1  29.0       7  116099.82
# 110019          575          0       0  36.0       4  178032.53
# 110020          712          0       1  31.0       2       0.00
# 110021          709          0       0  32.0       3       0.00
# 110022          621          0       0  37.0       7   87848.39
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
df.describe()
# Out:
#          CreditScore      Geography         Gender            Age  \
# count  275057.000000  275057.000000  275057.000000  275057.000000
# mean      656.484939       0.646401       0.563854      38.124415
# std        80.188100       0.815940       0.495907       8.864927
# min       350.000000       0.000000       0.000000      18.000000
# 25%       597.000000       0.000000       0.000000      32.000000
# 50%       659.000000       0.000000       1.000000      37.000000
# 75%       710.000000       1.000000       1.000000      42.000000
# max       850.000000       2.000000       1.000000      92.000000
#
#               Tenure        Balance  NumOfProducts      HasCrCard  \
# count  275057.000000  275057.000000  275057.000000  275057.000000
# mean        5.010867   55420.296450       1.554002       0.753589
# std         2.806173   62805.933171       0.546178       0.430921
# min         0.000000       0.000000       1.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275057 entries, 0 to 110022
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CreditScore      275057 non-null  int64
#  1   Geography        275057 non-null  int64
#  2   Gender           275057 non-null  int64
#  3   Age              275057 non-null  float64
#  4   Tenure           275057 non-null  int64
#  5   Balance          275057 non-null  float64
#  6   NumOfProducts    275057 non-null  int64
#  7   HasCrCard        275057 non-null  float64
#  8   IsActiveMember   275057 non-null  float64
#  9   EstimatedSalary  275057 non-null  float64
#  10  Exited           165034 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 25.2 MB

# %%
df_test = df[df['Exited'].isnull()]
df_train  = df[df['Exited'].isnull() == False]

# %%
df_train
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          2       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 165029          667          2       0  33.0       2       0.00
# 165030          792          0       1  35.0       3       0.00
# 165031          565          0       1  31.0       5       0.00
# 165032          554          2       0  30.0       7  161533.00
# 165033          850          0       1  31.0       1       0.00
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                   2        1.0             0.0        181449.97     0.0
# ...

# %%
df_train.shape
# Out:
# (165034, 11)

# %%
X = df_train.drop('Exited',axis =1)
y = df_train['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)
df_test_scaled = sc.transform(df_test)

# %%
plt.subplots(figsize = (24,9))
plt.subplot(1,2,1)
sns.boxplot(X_train)
plt.subplot(1,2,2)

sns.boxplot(X_train_scaled)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_9172\1515631093.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
log_reg_pred = log_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
pred = log_reg_pred
print('Accurecy is ',accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
# Accurecy is  0.7870148756324417
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.97      0.88     52102
#          1.0       0.48      0.12      0.19     13912
#
#     accuracy                           0.79     66014
#    macro avg       0.64      0.54      0.53     66014
# weighted avg       0.74      0.79      0.73     66014
#
# [[50317  1785]
#  [12275  1637]]

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
svc_pred = svc.predict(X_test)

# %%
def print_report( test,pred):
#     pred = svc_pred
    print('Accurecy is ',accuracy_score(test,pred))
    print(classification_report(test,pred))
    print(confusion_matrix(test,pred))

# %%
pred = svc_pred
print('Accurecy is ',accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
# Accurecy is  0.7892568243099949
#               precision    recall  f1-score   support
#
#          0.0       0.79      1.00      0.88     52102
#          1.0       0.00      0.00      0.00     13912
#
#     accuracy                           0.79     66014
#    macro avg       0.39      0.50      0.44     66014
# weighted avg       0.62      0.79      0.70     66014
#
# [[52102     0]
#  [13912     0]]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.naive_bayes import BernoulliNB
nb = BernoulliNB()
nb.fit(X_train,y_train)
nb_pred = nb.predict(X_test)

# %%
print_report(y_test,nb_pred)
# Out:
# Accurecy is  0.793346865816342
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.96      0.88     52102
#          1.0       0.53      0.18      0.27     13912
#
#     accuracy                           0.79     66014
#    macro avg       0.67      0.57      0.57     66014
# weighted avg       0.75      0.79      0.75     66014
#
# [[49848  2254]
#  [11388  2524]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
rd_pred = rf.predict(X_test)

# %%
print_report(y_test,rd_pred)
# Out:
# Accurecy is  0.857727148786621
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91     52102
#          1.0       0.71      0.54      0.62     13912
#
#     accuracy                           0.86     66014
#    macro avg       0.80      0.74      0.76     66014
# weighted avg       0.85      0.86      0.85     66014
#
# [[49077  3025]
#  [ 6367  7545]]

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(X_train,y_train)
ada_pred = ada.predict(X_test)

# %%
print_report(y_test, ada_pred)
# Out:
# Accurecy is  0.8609537370860727
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.92     52102
#          1.0       0.74      0.53      0.62     13912
#
#     accuracy                           0.86     66014
#    macro avg       0.81      0.74      0.77     66014
# weighted avg       0.85      0.86      0.85     66014
#
# [[49500  2602]
#  [ 6577  7335]]

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
gb_pred = gb.predict(X_test)

# %%
print_report(y_test,gb_pred)
# Out:
# Accurecy is  0.8647408125549126
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92     52102
#          1.0       0.75      0.54      0.63     13912
#
#     accuracy                           0.86     66014
#    macro avg       0.82      0.75      0.77     66014
# weighted avg       0.86      0.86      0.86     66014
#
# [[49589  2513]
#  [ 6416  7496]]

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=1000)
neigh.fit(X_train, y_train)
neigh_pred = neigh.predict(X_test)

# %%
print_report(y_test, neigh_pred)
# Out:
# Accurecy is  0.7892568243099949
#               precision    recall  f1-score   support
#
#          0.0       0.79      1.00      0.88     52102
#          1.0       0.00      0.00      0.00     13912
#
#     accuracy                           0.79     66014
#    macro avg       0.39      0.50      0.44     66014
# weighted avg       0.62      0.79      0.70     66014
#
# [[52102     0]
#  [13912     0]]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
param_test3 = {'min_samples_split':range(1000,2100,200), 'min_samples_leaf':range(30,71,10)}
gsearch3 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60,max_depth=9,max_features='sqrt', subsample=0.8, random_state=10), 
param_grid = param_test3, scoring='roc_auc',n_jobs=4, cv=5,)
gsearch3.fit(X_train,y_train)
# gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9172\305484768.py in <cell line: 5>()
#       3 param_grid = param_test3, scoring='roc_auc',n_jobs=4, cv=5)
#       4 gsearch3.fit(X_train,y_train)
# ----> 5 gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
#
# AttributeError: 'GridSearchCV' object has no attribute 'grid_scores_'

# %%
grid_pred = gsearch3.predict(X_test)

# %%
print_report(y_test , grid_pred)
# Out:
# Accurecy is  0.8654224861393038
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92     52102
#          1.0       0.74      0.55      0.63     13912
#
#     accuracy                           0.87     66014
#    macro avg       0.82      0.75      0.78     66014
# weighted avg       0.86      0.87      0.86     66014
#
# [[49417  2685]
#  [ 6199  7713]]

# %%
sub = pd.read_csv('Datasets/sample_submission.csv')

# %%
sub
# Out:
#             id  Exited
# 0       165034     0.5
# 1       165035     0.5
# 2       165036     0.5
# 3       165037     0.5
# 4       165038     0.5
# ...        ...     ...
# 110018  275052     0.5
# 110019  275053     0.5
# 110020  275054     0.5
# 110021  275055     0.5
# 110022  275056     0.5
#
# [110023 rows x 2 columns]

# %%
df_test.drop('Exited',axis =1 ,inplace  =True)
# Out:
# C:\Users\Sameer\AppData\Local\Temp\ipykernel_9172\2885055378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.drop('Exited',axis =1 ,inplace  =True)

# %%
pred = gsearch3.predict(df_test_scaled)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
sub['Exited'] = pred
